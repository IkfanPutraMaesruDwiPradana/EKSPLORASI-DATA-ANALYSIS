# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #load data

# %%
df= pd.read_csv('Data_Tanaman_Padi_Sumatera.csv')
df
# Out:
#     Provinsi   Tahun    Produksi  Luas Panen  Curah hujan  Kelembapan  \
# 0       Aceh  1993.0  1329536.00   323589.00       1627.0       82.00
# 1       Aceh  1994.0  1299699.00   329041.00       1521.0       82.12
# 2       Aceh  1995.0         NaN   339253.00       1476.0       82.72
# 3       Aceh  1996.0  1419128.00   348223.00       1557.0       83.00
# 4       Aceh  1997.0  1368074.00   337561.00       1339.0       82.46
# ..       ...     ...         ...         ...          ...         ...
# 219  Lampung  2016.0  3831923.00   390799.00       2317.6       79.40
# 220  Lampung  2017.0  4090654.00   396559.00       1825.1       77.04
# 221      NaN  2018.0  2488641.91   511940.93       1385.8       76.05
# 222  Lampung  2019.0  2164089.33   464103.42       1706.4       78.03
# 223  Lampung  2020.0  2604913.29   545149.05       2211.3       75.80
#
#      Suhu rata-rata
# 0             26.06
# 1             26.92
# 2             26.27
# 3             26.08
# ...

# %% [markdown]
# #detail informasi

# %% [markdown]
# #Filter data  5 baris awal

# %%
df.head()
# Out:
#   Provinsi   Tahun   Produksi  Luas Panen  Curah hujan  Kelembapan  \
# 0     Aceh  1993.0  1329536.0    323589.0       1627.0       82.00
# 1     Aceh  1994.0  1299699.0    329041.0       1521.0       82.12
# 2     Aceh  1995.0        NaN    339253.0       1476.0       82.72
# 3     Aceh  1996.0  1419128.0    348223.0       1557.0       83.00
# 4     Aceh  1997.0  1368074.0    337561.0       1339.0       82.46
#
#    Suhu rata-rata
# 0           26.06
# 1           26.92
# 2           26.27
# 3           26.08
# 4           26.31

# %% [markdown]
# column

# %%
df.columns = df.columns.str.strip()
df.columns
# Out:
# Index(['Provinsi', 'Tahun', 'Produksi', 'Luas Panen', 'Curah hujan',
#        'Kelembapan', 'Suhu rata-rata'],
#       dtype='object')

# %% [markdown]
# #info tipe data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 224 entries, 0 to 223
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Provinsi        219 non-null    object
#  1   Tahun           220 non-null    float64
#  2   Produksi        218 non-null    float64
#  3   Luas Panen      221 non-null    float64
#  4   Curah hujan     220 non-null    float64
#  5   Kelembapan      219 non-null    float64
#  6   Suhu rata-rata  220 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 12.4+ KB

# %% [markdown]
# #cek data kosong

# %%
df.isna().sum()
# Out:
# Provinsi          5
# Tahun             4
# Produksi          6
# Luas Panen        3
# Curah hujan       4
# Kelembapan        5
# Suhu rata-rata    4
# dtype: int64

# %%
df=df.dropna()
df
# Out:
#     Provinsi   Tahun    Produksi  Luas Panen  Curah hujan  Kelembapan  \
# 0       Aceh  1993.0  1329536.00   323589.00       1627.0       82.00
# 1       Aceh  1994.0  1299699.00   329041.00       1521.0       82.12
# 3       Aceh  1996.0  1419128.00   348223.00       1557.0       83.00
# 4       Aceh  1997.0  1368074.00   337561.00       1339.0       82.46
# 5       Aceh  1998.0  1404580.00   365892.00       1465.0       82.60
# ..       ...     ...         ...         ...          ...         ...
# 218  Lampung  2015.0  3641895.00   707266.00       1628.1       78.90
# 219  Lampung  2016.0  3831923.00   390799.00       2317.6       79.40
# 220  Lampung  2017.0  4090654.00   396559.00       1825.1       77.04
# 222  Lampung  2019.0  2164089.33   464103.42       1706.4       78.03
# 223  Lampung  2020.0  2604913.29   545149.05       2211.3       75.80
#
#      Suhu rata-rata
# 0             26.06
# 1             26.92
# 3             26.08
# 4             26.31
# ...

# %%
df.isna().sum()
# Out:
# Provinsi          0
# Tahun             0
# Produksi          0
# Luas Panen        0
# Curah hujan       0
# Kelembapan        0
# Suhu rata-rata    0
# dtype: int64

# %% [markdown]
# #rubah tipe data tahun ke int

# %%
df['Tahun'] = df['Tahun'].astype(int)
df
# Out:
# <ipython-input-10-135ae795a9cc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Tahun'] = df['Tahun'].astype(int)
#     Provinsi  Tahun    Produksi  Luas Panen  Curah hujan  Kelembapan  \
# 0       Aceh   1993  1329536.00   323589.00       1627.0       82.00
# 1       Aceh   1994  1299699.00   329041.00       1521.0       82.12
# 3       Aceh   1996  1419128.00   348223.00       1557.0       83.00
# 4       Aceh   1997  1368074.00   337561.00       1339.0       82.46
# 5       Aceh   1998  1404580.00   365892.00       1465.0       82.60
# ..       ...    ...         ...         ...          ...         ...
# 218  Lampung   2015  3641895.00   707266.00       1628.1       78.90
# ...

# %% [markdown]
# # cek duplicated

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #cek data unik di provinsi dan tahun

# %%
# Memeriksa nilai unik di kolom 'Provinsi'
unique_Provinsi = df['Provinsi'].unique()
print("Nilai unik di kolom 'Provinsi':", unique_Provinsi)

# Memeriksa nilai unik di kolom 'Tahun'
unique_Tahun = df['Tahun'].unique()
print("Nilai unik di kolom 'Tahun':", unique_Tahun)
# Out:
# Nilai unik di kolom 'Provinsi': ['Aceh' 'Sumatera Utara' 'Sumatera Barat' 'Riau' 'Jambi'
#  'Sumatera Selatan' 'Bengkulu' 'Lampung']
# Nilai unik di kolom 'Tahun': [1993 1994 1996 1997 1998 1999 2000 2001 2004 2005 2006 2007 2008 2009
#  2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020 1995 2002 2003]

# %% [markdown]
# #Visualisasikan jumlah nilai unik

# %%
# Menghitung jumlah nilai unik di kolom 'Provinsi' dan 'Tahun'
provinsi_counts = df['Provinsi'].value_counts()
tahun_counts = df['Tahun'].value_counts()

# Membuat visualisasi bar chart untuk jumlah nilai unik di kolom 'Provinsi'
plt.figure(figsize=(10, 6))
sns.barplot(x=provinsi_counts.index, y=provinsi_counts.values)
plt.xticks(rotation=90)
plt.title('Jumlah Unik Provinsi')
plt.xlabel('Provinsi')
plt.ylabel('Jumlah')
plt.show()

# Membuat visualisasi bar chart untuk jumlah nilai unik di kolom 'Tahun'
plt.figure(figsize=(17, 8))
sns.barplot(x=tahun_counts.index, y=tahun_counts.values)
plt.title('Jumlah Unik Tahun')
plt.xlabel('Tahun')
plt.ylabel('Jumlah')
plt.show()

# %% [markdown]
# #create a box plot

# %%
# Set ukuran figure agar lebih mudah dibaca
plt.figure(figsize=(12, 8))

# Membuat boxplot untuk setiap kolom numerik berdasarkan kategori Provinsi
sns.boxplot(x='Provinsi', y='Produksi', data=df)
plt.xticks(rotation=90)
plt.title('Boxplot Produksi Berdasarkan Provinsi')
plt.show()

plt.figure(figsize=(12, 8))
sns.boxplot(x='Provinsi', y='Luas Panen', data=df)
plt.xticks(rotation=90)
plt.title('Boxplot Luas Panen Berdasarkan Provinsi')
plt.show()

plt.figure(figsize=(12, 8))
sns.boxplot(x='Provinsi', y='Curah hujan', data=df)
plt.xticks(rotation=90)
plt.title('Boxplot Curah Hujan Berdasarkan Provinsi')
plt.show()

plt.figure(figsize=(12, 8))
sns.boxplot(x='Provinsi', y='Kelembapan', data=df)
plt.xticks(rotation=90)
plt.title('Boxplot Kelembapan Berdasarkan Provinsi')
plt.show()

plt.figure(figsize=(12, 8))
sns.boxplot(x='Provinsi', y='Suhu rata-rata', data=df)
plt.xticks(rotation=90)
plt.title('Boxplot Suhu Rata-Rata Berdasarkan Provinsi')
plt.show()

# %% [markdown]
# #corelation

# %%
# Membuat DataFrame dengan hanya kolom numerik yang relevan
kolom_numerik = ['Produksi', 'Luas Panen', 'Curah hujan', 'Kelembapan', 'Suhu rata-rata']
df_numerik = df[kolom_numerik]

# Menghitung matriks korelasi
corr_matrix = df_numerik.corr()

# Visualisasi korelasi menggunakan heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()
